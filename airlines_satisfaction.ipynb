# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mplt
import seaborn as sns

# %%
train_data=pd.read_csv("train.csv")
test_data=pd.read_csv("test.csv")

# %%
print(train_data.info())
train_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %%
train_data.isnull().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# ...

# %%
train_data.isna().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# ...

# %%
train_data.describe()
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %%
train_data['satisfaction'].value_counts()
# Out:
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: satisfaction, dtype: int64

# %%
test_data['satisfaction'].value_counts()
# Out:
# neutral or dissatisfied    14573
# satisfied                  11403
# Name: satisfaction, dtype: int64

# %%
sns.countplot(x='satisfaction',data=train_data)
# Out:
# <AxesSubplot:xlabel='satisfaction', ylabel='count'>

# %%
#train_plot=sns.load_dataset('train_data')
#print(train_plot.groupby(['Class']).mean()['satisfaction'])

# %%
mplt.figure(figsize=(20,15))
sns.heatmap(train_data.corr(),annot=True,cmap='coolwarm')
mplt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
df=pd.read_csv("train.csv")

df['satisfactionN'] =df['satisfaction'].apply(encode_satisfaction)

GenderN = pd.get_dummies(df['Gender'],drop_first=True)
CustomerN = pd.get_dummies(df['Customer Type'],drop_first=True)
TypeN = pd.get_dummies(df['Type of Travel'],drop_first=True)
ClassN = pd.get_dummies(df['Class'],drop_first=True)
df = pd.concat([df,GenderN,CustomerN,TypeN,ClassN],axis =1)
df.drop(['Gender','Customer Type','Type of Travel','Class'],inplace =True,axis = 1)

# %%
df.corr()['satisfactionN'].sort_values().drop('satisfactionN').plot(kind='bar')

#Analysing the catagorical variables, we came to know that People travelling in economy class and on a personal travel are unlikely to get satisfied.
#Now we know that people choosing online boarding are most satisfied.
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#         Unnamed: 0      id  Age  Flight Distance  Inflight wifi service  \
# 0                0   70172   13              460                      3
# 1                1    5047   25              235                      3
# 2                2  110028   26             1142                      2
# 3                3   24026   25              562                      2
# 4                4  119299   61              214                      3
# ...            ...     ...  ...              ...                    ...
# 103899      103899   94171   23              192                      2
# 103900      103900   73097   49             2347                      4
# 103901      103901   68825   30             1995                      1
# 103902      103902   54173   22             1000                      1
# 103903      103903   62567   27             1723                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# ...

# %%
print(train_data['Gender'].unique())
print(train_data['Customer Type'].unique())
print(train_data['Class'].unique())
print(train_data['Type of Travel'].unique())
print(train_data['satisfaction'].unique())
# Out:
# ['Male' 'Female']
# ['Loyal Customer' 'disloyal Customer']
# ['Eco Plus' 'Business' 'Eco']
# ['Personal Travel' 'Business travel']
# ['neutral or dissatisfied' 'satisfied']

# %%
print(train_data['Arrival Delay in Minutes'].mean())
print(train_data['Arrival Delay in Minutes'].median())
print(test_data['Arrival Delay in Minutes'].mean())
print(test_data['Arrival Delay in Minutes'].median())
# Out:
# 15.178678301832152
# 0.0
# 14.74085660217047
# 0.0

# %%
#Preprocessing the data 



def encode_gender(x):
    if x=="Male":
        return 0
    elif x=="Female":
        return 1
    else:
        return -1
    
def encode_satisfaction(x):
    if x=="satisfied":
        return 1
    elif x=="neutral or dissatisfied":
        return 0
    else:
        return -1
    
def encode_customerType(x):
    if x=="Loyal Customer":
        return 1
    elif x=="disloyal Customer":
        return 0
    else:
        return -1

def encode_travelType(x):
    if x=="Personal Travel":
        return 0
    elif x=="Business travel":
        return 1
    else:
        return -1
    
def encode_class(x):
    if x=='Business':
        return 2
    elif x=="Eco Plus":
        return 1
    elif x=="Eco":
        return 0
    else:
        return -1
    
def preprocess(df):
    df=df.drop(['Unnamed: 0','id'], axis=1)
    df['Gender']=df['Gender'].apply(encode_gender)
    df['satisfaction']=df['satisfaction'].apply(encode_satisfaction)
    df['Customer Type']=df['Customer Type'].apply(encode_customerType)
    df['Type of Travel']=df['Type of Travel'].apply(encode_travelType)
    df['Class']=df['Class'].apply(encode_class)
    df['Arrival Delay in Minutes'].fillna(df['Arrival Delay in Minutes'].median(), inplace = True)
    return df
    
train=preprocess(train_data)
test=preprocess(test_data)

# %%
train
# Out:
#         Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0            0              1   13               0      1              460
# 1            0              0   25               1      2              235
# 2            1              1   26               1      2             1142
# 3            1              1   25               1      2              562
# 4            0              1   61               1      2              214
# ...        ...            ...  ...             ...    ...              ...
# 103899       1              0   23               1      0              192
# 103900       0              1   49               1      2             2347
# 103901       0              0   30               1      2             1995
# 103902       1              0   22               1      0             1000
# 103903       0              1   27               1      2             1723
#
#         Inflight wifi service  Departure/Arrival time convenient  \
# ...

# %%
train.isna().sum()
# Out:
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %%
mplt.figure(figsize=(20,15))
sns.heatmap(test.corr(),annot = True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
#what is most correlated with satisafction and what is not?

# %%
train.corr()['satisfaction'].sort_values().drop('satisfaction').plot(kind='bar')

#Important continuous factors which contribute more correlation with customer satisfaction are 
#'Inflight wifi service','Flight Distance','cleanliness','on board service','seat comfort',
#'inflight entertainment','online boarding'
# Out:
# <AxesSubplot:>

# %%
#MAYBE GRAPH FOR SATISFACTION BASE ON CLASS,TYPE OF TRAVEL

print(train['Online boarding'].value_counts())
train['Online boarding'].plot(kind='hist', ec='white')
# Out:
# 4    30762
# 3    21804
# 5    20713
# 2    17505
# 1    10692
# 0     2428
# Name: Online boarding, dtype: int64
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.boxplot(x='satisfaction',y = 'Online boarding',data=train)
# Out:
# <AxesSubplot:xlabel='satisfaction', ylabel='Online boarding'>

# %%
sns.boxplot(x='satisfaction',y = 'Class',data=train)
# Out:
# <AxesSubplot:xlabel='satisfaction', ylabel='Class'>

# %%
sns.boxplot(x='satisfaction',y = 'Type of Travel',data=train)
# Out:
# <AxesSubplot:xlabel='satisfaction', ylabel='Type of Travel'>

# %%
train
# Out:
#         Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0            0              1   13               0      1              460
# 1            0              0   25               1      2              235
# 2            1              1   26               1      2             1142
# 3            1              1   25               1      2              562
# 4            0              1   61               1      2              214
# ...        ...            ...  ...             ...    ...              ...
# 103899       1              0   23               1      0              192
# 103900       0              1   49               1      2             2347
# 103901       0              0   30               1      2             1995
# 103902       1              0   22               1      0             1000
# 103903       0              1   27               1      2             1723
#
#         Inflight wifi service  Departure/Arrival time convenient  \
# ...

# %%
#Train and test data split

X_train=train.drop(['satisfaction'], axis=1)
y_train=train['satisfaction']

X_test=test.drop(['satisfaction'], axis=1)
y_test=test['satisfaction']

# %%
# Normalize Features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
X_train
y_train

X_test
y_test
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 25971    0
# 25972    1
# 25973    0
# 25974    1
# 25975    0
# Name: satisfaction, Length: 25976, dtype: int64

# %%
#may be do normalization?

# %%
print("X_train {}\nX_test {}\ny_train {}\ny_test {}".format(X_train.shape,X_test.shape,y_train.shape,y_test.shape))
# Out:
# X_train (103904, 22)
# X_test (25976, 22)
# y_train (103904,)
# y_test (25976,)

# %%
#Building classifiers-Random Forest
from sklearn.ensemble import RandomForestClassifier
randomforestclf=RandomForestClassifier(n_estimators=1000,criterion='entropy', max_depth=25,
         min_samples_leaf= 1,
         min_samples_split= 2,random_state=42,n_jobs=-1)
randomforestclf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=25, n_estimators=1000,
#                        n_jobs=-1, random_state=42)

# %%
from sklearn.model_selection import cross_val_score 
print("Cross Validation Scores: ", cross_val_score(randomforestclf, X_train,y_train))
# Out:
# Cross Validation Scores:  [0.96111833 0.96280256 0.96068524 0.96318753 0.96361886]

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,roc_auc_score, plot_confusion_matrix,plot_roc_curve
import matplotlib.pyplot as plt

y_pred = randomforestclf.predict(X_test)

print(classification_report(y_test,y_pred))
print('\n')
print('Confusion matrix : \n{}'.format(confusion_matrix(y_test,y_pred)))
print('\n')
print('Accuracy score : {}'.format(accuracy_score(y_test,y_pred)))
roc_auc_rf = roc_auc_score(y_test, y_pred)
print("ROC_AUC = {}".format(roc_auc_rf))
plot_confusion_matrix(randomforestclf, X_test, y_test,cmap=plt.cm.Blues, normalize = 'all')
plot_roc_curve(randomforestclf, X_test, y_test)

acc_random_forest = accuracy_score(y_test,y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     14573
#            1       0.97      0.94      0.96     11403
#
#     accuracy                           0.96     25976
#    macro avg       0.97      0.96      0.96     25976
# weighted avg       0.96      0.96      0.96     25976
#
#
#
# Confusion matrix :
# [[14296   277]
#  [  662 10741]]
#
#
# Accuracy score : 0.9638512473052048
# ROC_AUC = 0.9614686740501793

# %%
from sklearn.model_selection import GridSearchCV

rfc=RandomForestClassifier(random_state=42)
param_grid = { 
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}
scores=['precision','recall']
for score in scores:
    
    print("# Tuning hyper-parameters for %s" % score)
    print()
    
    clf=GridSearchCV(estimator=rfc, param_grid=param_grid, scoring='%s_macro' % score, cv=3 )
    clf.fit(X_train, y_train)
    
    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto', 'n_estimators': 500}
#
# Grid scores on development set:
#
# 0.910 (+/-0.005) for {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'n_estimators': 200}
# 0.910 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'n_estimators': 500}
# 0.910 (+/-0.005) for {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'n_estimators': 200}
# 0.910 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'n_estimators': 500}
# 0.910 (+/-0.005) for {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'n_estimators': 200}
# 0.910 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'n_estimators': 500}
# 0.922 (+/-0.005) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 200}
# ...

# %%
#Neural net classifier
from sklearn.neural_network import MLPClassifier
MLPclf=MLPClassifier(hidden_layer_sizes=(10,10,10),max_iter=500)
MLPclf.fit(X_train,y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(10, 10, 10), max_iter=500)

# %%
print("Cross Validation Scores: ", cross_val_score(MLPclf, X_train,y_train))
# Out:
# Cross Validation Scores:  [0.95558443 0.95693181 0.95659497 0.95909725 0.95866218]

# %%
y_pred = MLPclf.predict(X_test)

print(classification_report(y_test,y_pred))
print('\n')
print('Confusion matrix : \n{}'.format(confusion_matrix(y_test,y_pred)))
print('\n')
print('Accuracy score : {}'.format(accuracy_score(y_test,y_pred)))
roc_auc_mlp = roc_auc_score(y_test, y_pred)
print("ROC_AUC = {}".format(roc_auc_mlp))
plot_confusion_matrix(MLPclf, X_test, y_test,cmap=plt.cm.Blues, normalize = 'all')
plot_roc_curve(MLPclf, X_test, y_test)

acc_MLP = accuracy_score(y_test,y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96     14573
#            1       0.97      0.93      0.95     11403
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.95      0.96     25976
# weighted avg       0.96      0.96      0.96     25976
#
#
#
# Confusion matrix :
# [[14236   337]
#  [  786 10617]]
#
#
# Accuracy score : 0.9567677856482907
# ROC_AUC = 0.953972906868654

# %%
#Hyper tuning the parameters of Neural network
from sklearn.model_selection import GridSearchCV

mlp=MLPClassifier(random_state=42)
tuned_parameters = {
    
'solver': ['adam', 'lbfgs', 'sgd'],
'max_iter': [500,750,1000, 1200, 1500, 2000],
'hidden_layer_sizes': [(10,10,10), (10, 5), (5,5), (100, 10, 50)],
'alpha': [.0001, .005],
'learning_rate': ['constant', 'adaptive'],
'activation':['identity','logistic','tanh','relu']   
    
}
scores=['precision','recall']
for score in scores:
    
    print("# Tuning hyper-parameters for %s" % score)
    print()
    
    clf=GridSearchCV(estimator=mlp, param_grid=tuned_parameters, scoring='%s_macro' % score, cv=3 )
    clf.fit(X_train, y_train)
    
    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
# C:\Users\rishabhstha\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Users\rishabhstha\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ...

# %%
#accuracy score incereased by 0.04 points after normalizing

# %%
#Naive Bayes classifier
from sklearn.naive_bayes import GaussianNB
NBclf=GaussianNB()
NBclf.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
print("Cross Validation Scores: ", cross_val_score(NBclf, X_train,y_train))
# Out:
# Cross Validation Scores:  [0.86242241 0.86348106 0.86237428 0.86530966 0.87271415]

# %%
y_pred=NBclf.predict(X_test)
print(classification_report(y_test,y_pred))
print('\n')
print('Confusion matrix : \n{}'.format(confusion_matrix(y_test,y_pred)))
print('\n')
print('Accuracy score : {}'.format(accuracy_score(y_test,y_pred)))
roc_auc_nb = roc_auc_score(y_test, y_pred)
print("ROC_AUC = {}".format(roc_auc_nb))
plot_confusion_matrix(NBclf, X_test, y_test,cmap=plt.cm.Blues, normalize = 'all')
plot_roc_curve(NBclf,X_test, y_test)


acc_NB = accuracy_score(y_test,y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88     14573
#            1       0.86      0.82      0.84     11403
#
#     accuracy                           0.86     25976
#    macro avg       0.86      0.86      0.86     25976
# weighted avg       0.86      0.86      0.86     25976
#
#
#
# Confusion matrix :
# [[13073  1500]
#  [ 2077  9326]]
#
#
# Accuracy score : 0.8622959655066215
# ROC_AUC = 0.8574624371416897

# %%
print('Accuracy of different models:\n')
print("Random Forest {}\n MLPClassifier {}\nNaive Bayes {}\n".format(acc_random_forest,acc_MLP,acc_NB))

print('ROC Area Under Curve of different models:\n')
print("Random Forest {}\n MLPClassifier {}\nNaive Bayes {}\n".format(roc_auc_rf,roc_auc_mlp,roc_auc_nb))
# Out:
# Accuracy of different models:
#
# Random Forest 0.9638512473052048
#  MLPClassifier 0.9567677856482907
# Naive Bayes 0.8622959655066215
#
# ROC Area Under Curve of different models:
#
# Random Forest 0.9614686740501793
#  MLPClassifier 0.953972906868654
# Naive Bayes 0.8574624371416897
